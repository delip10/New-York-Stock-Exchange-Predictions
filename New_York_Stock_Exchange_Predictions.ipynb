# %%
import numpy as np # data processed in the form of array
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os #libray used to working in operating system files and processes
import matplotlib.pyplot as plt #data visulization library
#print(os.listdir(r"C:\Users\SUKUN\Downloads\nyse")) #checking the files in folder nyse in downloads

# %%
#calling the file in nyse named prices.csv
df =pd.read_csv("prices.csv", header=0)
df
# Out:
#                        date symbol        open       close         low  \
# 0       2016-01-05 00:00:00   WLTW  123.430000  125.839996  122.309998
# 1       2016-01-06 00:00:00   WLTW  125.239998  119.980003  119.940002
# 2       2016-01-07 00:00:00   WLTW  116.379997  114.949997  114.930000
# 3       2016-01-08 00:00:00   WLTW  115.480003  116.620003  113.500000
# 4       2016-01-11 00:00:00   WLTW  117.010002  114.970001  114.089996
# ...                     ...    ...         ...         ...         ...
# 438300           2013-09-10   ADBE   47.619999   48.020000   47.509998
# 438301           2013-09-10    ADI   47.730000   47.880001   47.520000
# 438302           2013-09-10    ADM   36.209999   36.080002   35.889999
# 438303           2013-09-10    ADP   74.380001   73.740000   73.740000
# 438304             2013-09-    NaN         NaN         NaN         NaN
#
#               high     volume
# 0       126.250000  2163600.0
# 1       125.540001  2386400.0
# 2       119.739998  2489500.0
# 3       117.440002  2006300.0
# 4       117.330002  1408600.0
# ...            ...        ...
# 438300   48.060001  2831100.0
# 438301   47.950001  1686200.0
# 438302   36.400002  2396000.0
# 438303   74.380001  3594600.0
# 438304         NaN        NaN
#
# [438305 rows x 7 columns]

# %%
#size of the dataset in 851264 rows and 7 columns
print(df.shape)
# Out:
# (438305, 7)

# %%
# takes 20 different and unique from symbol
df.symbol.unique()[0:20]
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN'], dtype=object)

# %%
# finind the length of column named symbol
print(len(df.symbol.values))
# Out:
# 438305

# %%
#gives the details of each columns of the dataset like mean, max etc
df.describe()
# Out:
#                 open          close            low           high  \
# count  438304.000000  438304.000000  438304.000000  438304.000000
# mean       58.229492      58.252926      57.603821      58.847681
# std        65.270729      65.279236      64.616901      65.907258
# min         0.850000       0.860000       0.830000       0.880000
# 25%        29.250000      29.267415      28.930000      29.580000
# 50%        44.810001      44.840000      44.349998      45.270000
# 75%        66.709999      66.750000      66.040001      67.410004
# max       992.030029     969.890015     969.450012     994.979980
#
#              volume
# count  4.383040e+05
# mean   6.284877e+06
# std    1.524572e+07
# min    0.000000e+00
# 25%    1.324500e+06
# 50%    2.764200e+06
# 75%    5.890400e+06
# max    8.596434e+08

# %%
#checking whether their is any null value in the dataset
# .sum() will give the total no. of null value column vise 
df.isnull().sum()
# Out:
# date      0
# symbol    1
# open      1
# close     1
# low       1
# high      1
# volume    1
# dtype: int64

# %%
# taking all the unique or one time value in the date column 
df.date.unique()
# Out:
# array(['2016-01-05 00:00:00', '2016-01-06 00:00:00',
#        '2016-01-07 00:00:00', ..., '2013-09-09 00:00:00', '2013-09-10',
#        '2013-09-'], dtype=object)

# %%
#calling the file in nyse named securities.csv
comp_info = pd.read_csv('securities.csv')
comp_info
# Out:
#     Ticker symbol                Security SEC filings             GICS Sector  \
# 0             MMM              3M Company     reports             Industrials
# 1             ABT     Abbott Laboratories     reports             Health Care
# 2            ABBV                  AbbVie     reports             Health Care
# 3             ACN           Accenture plc     reports  Information Technology
# 4            ATVI     Activision Blizzard     reports  Information Technology
# ..            ...                     ...         ...                     ...
# 500          YHOO              Yahoo Inc.     reports  Information Technology
# 501           YUM         Yum! Brands Inc     reports  Consumer Discretionary
# 502           ZBH  Zimmer Biomet Holdings     reports             Health Care
# 503          ZION           Zions Bancorp     reports              Financials
# 504           ZTS                  Zoetis     reports             Health Care
#
#                   GICS Sub Industry   Address of Headquarters  \
# 0          Industrial Conglomerates       St. Paul, Minnesota
# 1             Health Care Equipment   North Chicago, Illinois
# 2                   Pharmaceuticals   North Chicago, Illinois
# 3    IT Consulting & Other Services           Dublin, Ireland
# 4       Home Entertainment Software  Santa Monica, California
# ..                              ...                       ...
# 500    Internet Software & Services     Sunnyvale, California
# 501                     Restaurants      Louisville, Kentucky
# 502           Health Care Equipment           Warsaw, Indiana
# 503                  Regional Banks      Salt Lake City, Utah
# 504                 Pharmaceuticals  Florham Park, New Jersey
#
#     Date first added      CIK
# 0                NaN    66740
# 1         31-03-1964     1800
# 2         31-12-2012  1551152
# 3         06-07-2011  1467373
# 4         31-08-2015   718877
# ..               ...      ...
# 500              NaN  1011006
# 501       06-10-1997  1041061
# 502              NaN  1136869
# 503              NaN   109380
# 504       21-06-2013  1555280
#
# [505 rows x 8 columns]

# %%
# taking total no. of unique values in column Ticket symbol
comp_info["Ticker symbol"].nunique()
# Out:
# 505

# %%
# for locating specific data here.... in security column of string that starts with "Face"
comp_info.loc[comp_info.Security.str.startswith('Face') , :]
# Out:
#     Ticker symbol  Security SEC filings             GICS Sector  \
# 181            FB  Facebook     reports  Information Technology
#
#                 GICS Sub Industry Address of Headquarters Date first added  \
# 181  Internet Software & Services  Menlo Park, California       23-12-2013
#
#          CIK
# 181  1326801

# %%
# here we locate Ticker symbol of company with security like Yahoo, Xerox, Adobe etc 
# then taking their no. of times entry and thier "Ticker symbol"
comp_plot = comp_info.loc[(comp_info["Security"] == 'Yahoo Inc.') | (comp_info["Security"] == 'Xerox Corp.') | (comp_info["Security"] == 'Adobe Systems Inc')
              | (comp_info["Security"] == 'Microsoft Corp.') | (comp_info["Security"] == 'Adobe Systems Inc') 
              | (comp_info["Security"] == 'Facebook') | (comp_info["Security"] == 'Goldman Sachs Group') , ["Ticker symbol"] ]["Ticker symbol"] 
print(comp_plot)
# Out:
# 6      ADBE
# 181      FB
# 212      GS
# 306    MSFT
# 496     XRX
# 500    YHOO
# Name: Ticker symbol, dtype: object

# %%
def plotter(code):
    # creating variable for whole notebook
    global closing_stock ,opening_stock
    #creating plot of all 6 company for opening and closing
    f, axs = plt.subplots(2,2,figsize=(8,8))
    # total 12 graphs
    # creating plot opening prize of particular company
    plt.subplot(212)
    #taking name of the company as code
    company = df[df['symbol']==code]
    #taking the values of one company and taking its open column values
    company = company.open.values.astype('float32')
    #reshaping the open column value in 1D and calling it opening_stock
    company = company.reshape(-1, 1)
    # putting the value of company in opening_stock 
    opening_stock = company
    # plotting the data with green graph between "Time" and "prices vs time"
    
    plt.grid(True)# enalbling the grid in graph
    plt.xlabel('Time') # setting X axis as time
    plt.ylabel(code + " open stock prices") # setting Y axis as company name + open stock prices
    plt.title('prices Vs Time') # setting title
    plt.plot(company , 'g') # calling the graph with green graph line
    
    # creating plot closing prize of particular company
    plt.subplot(211)
    #taking name of the company as code
    company_close = df[df['symbol']==code]
    #taking the values of one company and taking its close column values
    company_close = company_close.close.values.astype('float32')
    #reshaping the open column value in 1D and calling it closing_stock
    company_close = company_close.reshape(-1, 1)
    # putting company_close value in closing_stock 
    closing_stock = company_close
    # plotting the data graph between "Time" and "prices vs time"
    
    plt.xlabel('Time') # setting x axis as time
    plt.ylabel(code + " close stock prices")# setting y axis as company name + open stock prices
    plt.title('prices Vs Time') # setting title as price vs time
    plt.grid(True) # enabling the grid in graph
    plt.plot(company_close , 'b') #creating the data graph in blue graph line
    plt.show() # calling the graph

# calling the graphs through the function    
for i in comp_plot:
    plotter(i)

# %%
#taking the values of closing_stock in a single list
closing_stock[:,0]
# Out:
# array([17.1 , 17.23, 17.17, 16.7 , 16.7 , 16.74, 16.68, 16.9 , 17.12,
#        16.82, 16.75, 16.38, 16.2 , 15.88, 15.86, 15.99, 15.98, 15.44,
#        15.01, 15.05, 15.17, 15.46, 15.01, 15.19, 14.99, 15.07, 14.8 ,
#        15.22, 15.17, 15.41, 15.44, 15.54, 15.58, 15.49, 15.38, 15.59,
#        15.24, 15.31, 15.79, 15.73, 15.57, 15.81, 16.06, 16.52, 16.53,
#        16.79, 16.53, 16.32, 16.46, 16.36, 16.5 , 16.56, 16.44, 16.34,
#        16.03, 16.09, 16.32, 16.54, 16.56, 16.61, 16.53, 16.29, 16.51,
#        16.92, 16.87, 17.35, 17.52, 17.64, 18.18, 18.38, 18.97, 18.17,
#        18.39, 18.38, 17.45, 17.72, 17.64, 17.39, 16.92, 16.75, 16.97,
#        16.53, 16.95, 16.32, 16.49, 15.92, 15.29, 16.33, 16.41, 16.47,
#        16.14, 16.39, 16.27, 16.03, 15.79, 15.1 , 15.48, 15.54, 15.31,
#        15.45, 15.69, 15.34, 15.02, 15.18, 15.43, 15.  , 14.94, 14.79,
#        14.69, 15.1 , 15.29, 15.17, 15.65, 15.49, 15.6 , 15.54, 15.21,
#        15.09, 15.23, 14.83, 14.81, 14.73, 14.04, 13.84, 14.09, 14.07,
#        14.13, 14.4 , 14.6 , 14.89, 14.94, 15.52, 15.37, 15.37, 14.9 ,
#        15.1 , 15.2 , 13.91, 13.88, 13.99, 14.15, 13.95, 13.87, 13.76,
#        13.88, 14.  , 13.94, 14.18, 14.16, 14.34, 14.4 , 14.35, 13.87,
#  23.38 23.52 23.3  23.48 23.83 24.2  24.49 24.69 23.98 23.79 23.7  23.26
#  23.47 23.95 24.38 24.75 25.2  24.68 24.43 24.73 24.3  24.97 25.07 25.17
#  26.07 26.41 26.24 26.83 26.39 26.64 27.34 26.58 26.52 26.58 27.   26.54
#  26.02 26.33 26.07 25.81 26.33 26.3  26.39 26.26 25.75 26.21 27.04 26.74
#  26.4  25.89 26.37 26.28 26.54 26.66 26.24 25.35 25.19 24.07 24.96 25.29
#  25.47 25.13 25.24 24.99 25.59 25.68 25.53 26.68 26.56 27.04 27.23 27.34
#  26.88 29.66 29.66 29.11 27.86 27.36 27.84 28.27 28.11 27.93 28.05 28.09
#  27.96 27.65 27.67 27.32 27.39 27.48 27.68 28.35 28.34 28.05 27.14 27.32
#  26.91 27.12 27.06 27.9  27.99 27.7  27.   27.11 27.3  27.12 27.78 28.07
#  28.23 28.17 29.24]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1)) #scaling features between 0 and 1
stocks = scaler.fit_transform(stocks) # it will start learning algo and then provide scaled and dimension reduced output

# %%
train = int(len(stocks) * 0.80) #creating sizes of train and taking 80% percentage of the part
test = len(stocks) - train #creating sizes of test as total minus train

# %%
#sizes of train and test
print(train , test)
# Out:
# 741 186

# %%
#divinding the values of stocks data to train from 0 to 1409 i.e 80% data
train = stocks[0:train]
print(train)
# Out:
# [[0.3236403 ]
#  [0.3306408 ]
#  [0.3274098 ]
#  [0.30210018]
#  [0.30210018]
#  [0.30425417]
#  [0.3010232 ]
#  [0.3128702 ]
#  [0.32471734]
#  [0.30856216]
#  [0.3047927 ]
#  [0.284868  ]
#  [0.27517503]
#  [0.25794291]
#  [0.25686592]
#  [0.26386642]
#  [0.2633279 ]
#  [0.23424876]
#  [0.21109319]
#  [0.21324718]
#  [0.21970922]
#  [0.23532581]
#  [0.21109319]
#  [0.22078621]
#  [0.21001613]
#  [0.21432418]
#  [0.19978458]
#  [0.22240174]
#  [0.21970922]
#  [0.2326333 ]
#  [0.23424876]
#  [0.2396338 ]
#  [0.24178785]
#  [0.23694128]
#  [0.23101777]
#  [0.24232632]
#  [0.22347873]
#  [0.22724825]
#  [0.2530964 ]
#  [0.24986535]
#  [0.24124932]
#  [0.2541734 ]
#  [0.26763594]
#  [0.29240716]
#  [0.29294562]
#  [0.30694675]
#  [0.29294562]
#  [0.281637  ]
#  [0.28917605]
#  [0.28379107]
#  [0.2913301 ]
#  [0.2945611 ]
#  [0.2880991 ]
#  [0.28271407]
#  [0.26602048]
#  [0.26925147]
#  [0.281637  ]
#  [0.29348415]
#  [0.2945611 ]
#  [0.29725367]
#  [0.29294562]
#  [0.2800216 ]
#  [0.29186863]
#  [0.3139472 ]
#  [0.31125474]
#  [0.3371029 ]
#  [0.34625745]
#  [0.35271943]
#  [0.38179862]
#  [0.3925686 ]
#  [0.42434025]
#  [0.3812601 ]
#  [0.39310712]
#  [0.3925686 ]
#  [0.34248793]
#  [0.3570274 ]
#  [0.35271943]
#  [0.33925682]
#  [0.3139472 ]
#  [0.3047927 ]
#  [0.31663972]
#  [0.29294562]
#  [0.20247716]
#  [0.19547659]
#  [0.20193863]
#  [0.19278407]
#  [0.19170702]
#  [0.20463115]
#  [0.21540117]
#  [0.21647817]
#  [0.22240174]
#  [0.21647817]
#  [0.21917069]
#  [0.23209476]
#  [0.24286485]
#  [0.2520194 ]
#  [0.24717289]
#  [0.25955844]
#  [0.25686592]
#  [0.2530964 ]
#  [0.25040388]
#  [0.26440495]
#  [0.24717289]
#  [0.24340332]
#  [0.266559  ]
#  [0.2633279 ]
#  [0.2552504 ]
#  [0.2611739 ]
#  [0.27571344]
#  [0.27894455]
#  [0.26925147]
#  [0.26602048]
#  [0.25632745]
#  [0.2552504 ]
#  [0.2600969 ]
#  [0.25794291]
#  [0.24717289]
#  [0.2600969 ]
#  [0.26925147]
#  [0.26440495]
#  [0.25578892]
#  [0.2520194 ]
#  [0.30048466]
#  [0.29402256]
#  [0.29725367]
#  [0.30694675]
#  [0.30963922]
#  [0.31556278]
#  [0.3241788 ]
#  [0.3381799 ]
#  [0.34302634]
#  [0.33925682]
#  [0.33117932]
#  [0.33225632]
#  [0.34571892]
#  [0.36402804]
#  [0.36295098]
#  [0.36618197]
#  [0.36456656]
#  [0.3914917 ]
#  [0.3850296 ]
#  [0.39364564]
#  [0.4028002 ]
#  [0.41303182]
#  [0.42218637]
#  [0.42110932]
#  [0.41895533]
#  [0.41357028]
#  [0.40172315]
#  [0.42218637]
#  [0.42003226]
#  [0.43672597]
#  [0.43672597]
#  [0.44911146]
#  [0.45395803]]

# %%
#divinding the values of stocks data to test from train ending to stock data ending i.e rest 20% data
test = stocks[len(train) : ]

# %%
#reshaping train data in 1D array form
train = train.reshape(len(train) , 1)
#reshaping test data in 1D array form
test = test.reshape(len(test) , 1)

# %%
#new train and test array shape
print(train.shape , test.shape)
# Out:
# (741, 1) (186, 1)

# %% [markdown]
# **process_data for the required input for LSTM.**

# %%
#creating function to create trainX,testX and target(trainY, testY)
def process_data(data , n_features):
    dataX, dataY = [], [] # creating data for dataset and dividing inta X,Y
    for i in range(len(data)-n_features-1):
        # taking i range from total size- 3 
        a = data[i:(i+n_features), 0]
        # her a is value of data from i to i+ n_features in 1D and putting it in dataX 
        dataX.append(a) #putting a in dataX
        #here dataY takes the value of data of i + n_features
        dataY.append(data[i + n_features, 0])
        # putting i+ n_features in  dataY
    return np.array(dataX), np.array(dataY)
# returning dataX and dataY in array

#so the stucture of trainX and trainY is somehow like this
# trainX=[[i1 , i2,...., i n_features ]] and trainY=[i + n_features]  
# trainY will show the future value of trainX values

# %% [markdown]
# **Here I am taking 2 past values to predict a single value. This has already been checked and optimized after taking several cases.**
# **TrainY is set in such a way that it will show the ahead value or future time value of the given data(trainX)
# So when we train the data it will learn to predict the future value of further ahead.**

# %%
n_features = 2
# and here we create train X,Y and test X,Y data where trainX, testX has two value is each block
trainX, trainY = process_data(train, n_features)
# testY, trainY has one value that will be of two step ahead of corresponding(testY,trainX) value
testX, testY = process_data(test, n_features)

# %%
# printing the structure of train X,Y and test X,Y
print(trainX.shape , trainY.shape , testX.shape , testY.shape)
# Out:
# (738, 2) (738,) (183, 2) (183,)

# %%
# reshaping trainX and testX to use in deeplearning model
trainX = trainX.reshape(trainX.shape[0] , 1 ,trainX.shape[1])
testX = testX.reshape(testX.shape[0] , 1 ,testX.shape[1])

# %%
import math # helps us do mathematical operations
from keras.models import Sequential # for setting layers one by one neural layer in model 
from keras.layers import Dense , BatchNormalization , Dropout , Activation # types of layers
from keras.layers import LSTM , GRU # types of RNN
from sklearn.preprocessing import MinMaxScaler #It puts the data in between given range to set data before putting layer
from sklearn.metrics import mean_squared_error # In this method the errors in column is squared and then mean is found 
from tensorflow.keras.optimizers import Adam , SGD , RMSprop # they are the algos that found the output for model

# %%
filepath="stock_weights1.hdf5"
from keras.callbacks import ReduceLROnPlateau , ModelCheckpoint
# the model reduce the learning rate where the value are not repeated or too close to reduce overfitting
lr_reduce = ReduceLROnPlateau(monitor='val_loss', factor=0.1, epsilon=0.0001, patience=1, verbose=1)
# for saving the best result value from the epoochs as checkpoints
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='max')
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
# creating model for training data using sequential to give series wise output between layers
model = Sequential()
# GRU or Gated Recurrent Unit used for matrix manipulation within Recurrent layer
model.add(GRU(256 , input_shape = (1 , n_features) , return_sequences=True))
#dropout is used to remove overfitting data on each layer of neural network
model.add(Dropout(0.4))
#Long Short Term Memory is a type of RNN specially used for time series problems
model.add(LSTM(256))
#dropout is used to remove overfitting data on each layer of neural network
model.add(Dropout(0.4))
#Dense layer are fully connected neural networks 
model.add(Dense(64 ,  activation = 'relu'))
model.add(Dense(1))
#for getting the details of our models
print(model.summary())
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 1, 256)            199680
#
#  dropout_6 (Dropout)         (None, 1, 256)            0
#
#  lstm_3 (LSTM)               (None, 256)               525312
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 64)                16448
#
#  dense_7 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 741,505
# Trainable params: 741,505
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# selecting the loss measurement metrics and optimizer for our model , to find out mean square error
model.compile(loss='mean_squared_error', optimizer=Adam(lr = 0.0005) , metrics = ['mean_squared_error'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# fitting the data i.e training the trainX, to relate to trainY
# epochs is the times each data in send to fit
# batch size is the size of information send at a time
# validation_data is the validation or data used for testing 
history = model.fit(trainX, trainY, epochs=100 , batch_size = 128 , 
          callbacks = [checkpoint , lr_reduce] , validation_data = (testX,testY))    
#callbacks are proper
# Out:
# Epoch 1/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0559 - mean_squared_error: 0.0559
# Epoch 1: val_loss improved from -inf to 0.40261, saving model to stock_weights1.hdf5
# 6/6 [==============================] - 6s 224ms/step - loss: 0.0559 - mean_squared_error: 0.0559 - val_loss: 0.4026 - val_mean_squared_error: 0.4026 - lr: 5.0000e-04
# Epoch 2/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0328 - mean_squared_error: 0.0328
# Epoch 2: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0311 - mean_squared_error: 0.0311 - val_loss: 0.2415 - val_mean_squared_error: 0.2415 - lr: 5.0000e-04
# Epoch 3/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0088 - mean_squared_error: 0.0088
# Epoch 3: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0813 - val_mean_squared_error: 0.0813 - lr: 5.0000e-04
# Epoch 4/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0039 - mean_squared_error: 0.0039
# Epoch 4: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0283 - val_mean_squared_error: 0.0283 - lr: 5.0000e-04
# Epoch 5/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0048 - mean_squared_error: 0.0048
# Epoch 5: val_loss did not improve from 0.40261
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 5.0000002374872565e-05.
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0653 - val_mean_squared_error: 0.0653 - lr: 5.0000e-04
# Epoch 6/100
# 4/6 [===================>..........] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 6: val_loss did not improve from 0.40261
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 5.000000237487257e-06.
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0701 - val_mean_squared_error: 0.0701 - lr: 5.0000e-05
# Epoch 7/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 7: val_loss did not improve from 0.40261
#
# Epoch 7: ReduceLROnPlateau reducing learning rate to 5.000000328436726e-07.
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0705 - val_mean_squared_error: 0.0705 - lr: 5.0000e-06
# Epoch 8/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 8: val_loss did not improve from 0.40261
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 5.000000555810402e-08.
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-07
# Epoch 9/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 9: val_loss did not improve from 0.40261
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-09.
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-08
# Epoch 10/100
# 4/6 [===================>..........] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 10: val_loss did not improve from 0.40261
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-10.
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-09
# Epoch 11/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 11: val_loss did not improve from 0.40261
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-11.
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-10
# Epoch 12/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 12: val_loss did not improve from 0.40261
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-12.
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-11
# Epoch 13/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 13: val_loss did not improve from 0.40261
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 5.000000413701855e-13.
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-12
# Epoch 14/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 14: val_loss did not improve from 0.40261
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 5.0000005221220725e-14.
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-13
# Epoch 15/100
# 4/6 [===================>..........] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 15: val_loss did not improve from 0.40261
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 5.000000589884709e-15.
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-14
# Epoch 16/100
# 4/6 [===================>..........] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 16: val_loss did not improve from 0.40261
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 5.000000759291298e-16.
# 6/6 [==============================] - 0s 30ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-15
# Epoch 17/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 17: val_loss did not improve from 0.40261
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 5.000000547533061e-17.
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-16
# Epoch 18/100
# 4/6 [===================>..........] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 18: val_loss did not improve from 0.40261
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 5.000000415184163e-18.
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-17
# Epoch 19/100
# 4/6 [===================>..........] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 19: val_loss did not improve from 0.40261
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 5.000000332466102e-19.
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-18
# Epoch 20/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 20: val_loss did not improve from 0.40261
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 5.000000229068525e-20.
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-19
# Epoch 21/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 21: val_loss did not improve from 0.40261
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 5.00000016444504e-21.
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-20
# Epoch 22/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 22: val_loss did not improve from 0.40261
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 5.000000245224397e-22.
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-21
# Epoch 23/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 23: val_loss did not improve from 0.40261
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 5.0000003461985925e-23.
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-22
# Epoch 24/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 24: val_loss did not improve from 0.40261
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 5.000000472416337e-24.
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-23
# Epoch 25/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 25: val_loss did not improve from 0.40261
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 5.000000393530247e-25.
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-24
# Epoch 26/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 26: val_loss did not improve from 0.40261
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 5.000000590745473e-26.
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-25
# Epoch 27/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 27: val_loss did not improve from 0.40261
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 5.000000714004989e-27.
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-26
# Epoch 28/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 28: val_loss did not improve from 0.40261
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 5.00000071400499e-28.
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-27
# Epoch 29/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 29: val_loss did not improve from 0.40261
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 5.000000617708492e-29.
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-28
# Epoch 30/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 30: val_loss did not improve from 0.40261
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 5.0000006177084924e-30.
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-29
# Epoch 31/100
# 4/6 [===================>..........] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 31: val_loss did not improve from 0.40261
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 5.0000007681717695e-31.
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-30
# Epoch 32/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 32: val_loss did not improve from 0.40261
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 5.000000956250865e-32.
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-31
# Epoch 33/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 33: val_loss did not improve from 0.40261
#
# Epoch 33: ReduceLROnPlateau reducing learning rate to 5.0000010738003005e-33.
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-32
# Epoch 34/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 34: val_loss did not improve from 0.40261
#
# Epoch 34: ReduceLROnPlateau reducing learning rate to 5.000001220737094e-34.
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-33
# Epoch 35/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 35: val_loss did not improve from 0.40261
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 5.000001037066102e-35.
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-34
# Epoch 36/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 36: val_loss did not improve from 0.40261
#
# Epoch 36: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-36.
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-35
# Epoch 37/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 37: val_loss did not improve from 0.40261
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 5.000000807477361e-37.
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-36
# Epoch 38/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 38: val_loss did not improve from 0.40261
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 5.000000628111158e-38.
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-37
# Epoch 39/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 39: val_loss did not improve from 0.40261
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 5.000000516007281e-39.
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-38
# Epoch 40/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 40: val_loss did not improve from 0.40261
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 5.000001076526666e-40.
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-39
# Epoch 41/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 41: val_loss did not improve from 0.40261
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 5.000001076526667e-41.
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-40
# Epoch 42/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 42: val_loss did not improve from 0.40261
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 4.99997305055738e-42.
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0000e-41
# Epoch 43/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 43: val_loss did not improve from 0.40261
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 4.9998329207109475e-43.
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 4.9998e-42
# Epoch 44/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 44: val_loss did not improve from 0.40261
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 5.002635517639597e-44.
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0026e-43
# Epoch 45/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 45: val_loss did not improve from 0.40261
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 5.0446744715693416e-45.
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.0447e-44
# Epoch 46/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 46: val_loss did not improve from 0.40261
#
# Epoch 46: ReduceLROnPlateau reducing learning rate to 5.6051938572992686e-46.
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 5.6052e-45
# Epoch 47/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 47: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 48/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 48: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 49/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 49: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 50/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 50: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 51/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 51: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 40ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 52/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 52: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 53/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 53: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 54/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 54: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 55/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 55: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 56/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 56: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 57/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 57: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 58/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 58: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 32ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 59/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 59: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 60/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 60: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 61/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 61: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 62/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 62: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 63/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 63: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 64/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 64: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 65/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 65: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 66/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 66: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 67/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 67: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 68/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 68: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 69/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 69: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 70/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 70: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 71/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 71: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 72/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 72: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 73/100
# 4/6 [===================>..........] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 73: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 31ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 74/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 74: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 75/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 75: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 76/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 76: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 77/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 77: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 78/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 78: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 79/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 79: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 80/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 80: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 38ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 81/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 81: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 82/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 82: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 83/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 83: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 35ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 84/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 84: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 85/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 85: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 86/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 86: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 87/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 87: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 88/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 88: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 89/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 89: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 90/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0022 - mean_squared_error: 0.0022
# Epoch 90: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 91/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 91: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 92/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 92: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 93/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 93: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 33ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 94/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0019 - mean_squared_error: 0.0019
# Epoch 94: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 95/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 95: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 39ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 96/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 96: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 37ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 97/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 97: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 34ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 98/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0021 - mean_squared_error: 0.0021
# Epoch 98: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 36ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 99/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 99: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 57ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00
# Epoch 100/100
# 5/6 [========================>.....] - ETA: 0s - loss: 0.0020 - mean_squared_error: 0.0020
# Epoch 100: val_loss did not improve from 0.40261
# 6/6 [==============================] - 0s 54ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0706 - val_mean_squared_error: 0.0706 - lr: 0.0000e+00

# %%
import matplotlib.pyplot as plt
# here comparing the loss with mean squared error
# it call the graph with labels, titlea, lines
plt.plot(history.history['mean_squared_error']) #from fitting 
plt.plot(history.history['val_mean_squared_error'])# val_mean_squared_error is property from callbacks
plt.title('model mean squared error') # setting the title of the graph
plt.ylabel('loss') # label of X axis
plt.xlabel('epoch')# label of y axis
plt.legend(['train', 'test'], loc='upper left') # key of the graph to tell difference between train and test graph
plt.show() # it call the graph with labels, titlea, lines
# summarize history for loss
# plt.plot is used to built the gra
plt.plot(history.history['loss']) # loss is the value of cost function for your traing data
plt.plot(history.history['val_loss'])# val_loss is the value of cost function for your cross-validation data 
plt.title('model loss')#  setting the title of the graph
plt.ylabel('loss') # label of X axis
plt.xlabel('epoch') # label of Y axis
plt.legend(['train', 'test'], loc='upper left')  # key of the graph to tell difference between train and test graph
plt.show() # it call the graph with labels, titles, lines

# %%
def model_score(model, X_train, y_train, X_test, y_test):
    # model. evaluate gives us the overall accuracy and loss
    trainScore = model.evaluate(X_train, y_train, verbose=0)
    #here for trainX and trainY we print mean square error and root mean square error
    print('Train Score: %.5f MSE (%.2f RMSE)' % (trainScore[0], math.sqrt(trainScore[0])))
    # model. evaluate gives us the overall accuracy and loss
    testScore = model.evaluate(X_test, y_test, verbose=0)
    #here for testX and testY we print mean square error and root mean square error
    print('Test Score: %.5f MSE (%.2f RMSE)' % (testScore[0], math.sqrt(testScore[0])))
    # returns the loss of train and test 
    return trainScore[0], testScore[0]

# will return the value of overall mean squared error
model_score(model, trainX, trainY , testX, testY)
# Out:
# Train Score: 0.00172 MSE (0.04 RMSE)
# Test Score: 0.07057 MSE (0.27 RMSE)
# (0.0017211148515343666, 0.070573590695858)

# %%
#predicting the value for testX
pred = model.predict(testX)
#converting pred list in 1D array so that it will be efficient in ploting
pred = scaler.inverse_transform(pred)
# prediction here will be the stock market price of further ahead of given company details
pred[:10]
# taking pred from 1 to 10
# Out:
# array([[17.490828],
#        [17.54048 ],
#        [17.618927],
#        [17.617062],
#        [17.596573],
#        [17.609455],
#        [17.56421 ],
#        [17.542437],
#        [17.597803],
#        [17.584734]], dtype=float32)

# %%
# reshaping testY in single array
testY = testY.reshape(testY.shape[0] , 1)
#converting reshaped list in 1D array so that it will be efficient in ploting
testY = scaler.inverse_transform(testY)
# taking testY from 1 to 10
testY[:10]
# Out:
# array([[19.64],
#        [19.69],
#        [19.62],
#        [19.6 ],
#        [19.69],
#        [19.35],
#        [19.65],
#        [19.57],
#        [19.6 ],
#        [19.5 ]], dtype=float32)

# %%
# ploting the graph of stock prices with time
print("Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices")
plt.rcParams["figure.figsize"] = (15,7)
# testY is the blue line grap
plt.plot(testY , 'b')
# pred is the red line grap
plt.plot(pred , 'r')
# setting x asix as time
plt.xlabel('Time')
# setting y asux as stock prices
plt.ylabel('Stock Prices')
# setting title 
plt.title('Check the accuracy of the model with time')
# enabling grids in graph 
plt.grid(True)
# it call the graph with labels, titles, lines
plt.show()
# Out:
# Red - Predicted Stock Prices  ,  Blue - Actual Stock Prices
